# %% [markdown]
# # 07 — MITRE ATT&CK mapping (reporting)

# %%
import os
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Check if drive is already mounted
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')
else:
  print("Drive is already mounted.")

print("Done!")

# Filepath Search
#search_term = "your_filename.ext"  # Change this
search_term = "synthetic_assets.csv"
# !find /content/drive/MyDrive -maxdepth 15 -type f -iname "synthetic_assets.csv" -print
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive is already mounted.
# Done!
# /content/drive/MyDrive/data/synthetic_assets.csv

# %%
# !pip -q install pandas numpy matplotlib  # safe to re-run

# %%
import pandas as pd
mapping = pd.DataFrame([
  {'control':'private_endpoints_only','intent':'reduce exfil paths','technique':'T1041 Exfiltration Over C2 Channel'},
  {'control':'mfa_required','intent':'resist credential abuse','technique':'T1078 Valid Accounts'},
  {'control':'explicit_allow_per_principal','intent':'limit lateral movement','technique':'T1021 Remote Services'},
  {'control':'step_up_on_anomaly','intent':'continuous verification','technique':'T1562 Impair Defenses'}
])
mapping
# Out:
#                         control                   intent  \
# 0        private_endpoints_only       reduce exfil paths
# 1                  mfa_required  resist credential abuse
# 2  explicit_allow_per_principal   limit lateral movement
# 3            step_up_on_anomaly  continuous verification
#
#                             technique
# 0  T1041 Exfiltration Over C2 Channel
# 1                T1078 Valid Accounts
# 2               T1021 Remote Services
# 3               T1562 Impair Defenses

# %%
mapping.to_csv('/content/drive/MyDrive/data/attck_mapping.csv', index=False)
print('Wrote data/attck_mapping.csv')
# Out:
# Wrote data/attck_mapping.csv
