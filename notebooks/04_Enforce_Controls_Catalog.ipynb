# %% [markdown]
# # 04 — Protect (Enforce): Controls catalog by tier (vendor-neutral)

# %%
# !pip -q install pandas numpy matplotlib  # safe to re-run

# %%
controls = {
 'tier0_deny_by_default': [
   'no_public_access',
   'private_endpoints_only',
   'explicit_allow_per_principal',
   'no_legacy_auth',
   'break_glass_with_approval'
 ],
 'tier1_strict_conditional': [
   'mfa_required',
   'device_posture_required',
   'trusted_network_or_mtls',
   'session_limits',
   'step_up_on_anomaly'
 ],
 'tier2_strong_auth': [
   'mfa_required',
   'least_privilege_roles',
   'token_scopes_restricted'
 ],
 'tier3_baseline': [
   'baseline_auth',
   'logging_enabled'
 ]
}
controls
# Out:
# {'tier0_deny_by_default': ['no_public_access',
#   'private_endpoints_only',
#   'explicit_allow_per_principal',
#   'no_legacy_auth',
#   'break_glass_with_approval'],
#  'tier1_strict_conditional': ['mfa_required',
#   'device_posture_required',
#   'trusted_network_or_mtls',
#   'session_limits',
#   'step_up_on_anomaly'],
#  'tier2_strong_auth': ['mfa_required',
#   'least_privilege_roles',
#   'token_scopes_restricted'],
#  'tier3_baseline': ['baseline_auth', 'logging_enabled']}
